# %%
# Extract periode, tahun, provinsi filter values

import requests
from bs4 import BeautifulSoup

URL = "https://djpk.kemenkeu.go.id/portal/data/apbd"
r = requests.get(URL)
soup = BeautifulSoup(r.text, "html.parser")

periode_dropdownid = "sel_periode"
tahun_dropdownid = "sel_tahun"
provinsi_dropdownid = "sel_provinsi"

def get_dropdown_values(soup, select_id):
    dropdown = soup.find("select", {"id": select_id})
    if not dropdown:
        return []
    return [(opt["value"], opt.get_text(strip=True))
            for opt in dropdown.find_all("option") if opt.get("value")]

provinsi_list = get_dropdown_values(soup, provinsi_dropdownid)
periode_list  = get_dropdown_values(soup, periode_dropdownid)
tahun_list    = get_dropdown_values(soup, tahun_dropdownid)


print("Provinsi:", provinsi_list[:5])  # show first few
print("Periode:", periode_list)
print("Tahun:", tahun_list)
# Out:
# Provinsi: [('--', 'Semua Provinsi'), ('01', 'Provinsi Aceh'), ('02', 'Provinsi Sumatera Utara'), ('03', 'Provinsi Sumatera Barat'), ('04', 'Provinsi Riau')]
# Periode: [('1', 'Januari'), ('2', 'Februari'), ('3', 'Maret'), ('4', 'April'), ('5', 'Mei'), ('6', 'Juni'), ('7', 'Juli'), ('8', 'Agustus'), ('9', 'September'), ('10', 'Oktober'), ('11', 'November'), ('12', 'Desember')]
# Tahun: [('2026', '2026'), ('2025', '2025'), ('2024', '2024'), ('2023', '2023'), ('2022', '2022'), ('2021', '2021'), ('2020', '2020'), ('2019', '2019'), ('2018', '2018'), ('2017', '2017'), ('2016', '2016'), ('2015', '2015'), ('2014', '2014'), ('2013', '2013'), ('2012', '2012'), ('2011', '2011')]

# %%
# Remove "Semua Provinsi" from the list
provinsi_list = [p for p in provinsi_list if p[1] != "Semua Provinsi"]

# %%
# Hapus tahun 2026
tahun_list = [t for t in tahun_list if t[0] != '2026']

# Start from 2018 to shorten loop time
tahun_list = [t for t in tahun_list if int(t[0])>2017 ]

# %%
# Scrape the APBD data from each provinsi, periode, tahun combination
import os
import requests
import pandas as pd
from io import BytesIO, StringIO
import csv
from tqdm import tqdm
import itertools

# Base download URL (you need to confirm exact endpoint from Inspect > Network)
BASE_URL = "https://djpk.kemenkeu.go.id/portal/csv_apbd"


# Create output folder
os.makedirs("apbd_excels", exist_ok=True)

# Pre-create an empty dataframe to which we'll append all the data
all_data = pd.DataFrame()

# Loop over combinations
loop_length = len(provinsi_list)*len(periode_list)*len(tahun_list)
i = 0

for provinsi, periode, tahun in itertools.product(provinsi_list, periode_list, tahun_list):
    i = i+1
    print(f"Progress: {i/loop_length:.3%}")

    # Skip future periods
    if (tahun == '2025') and periode in [9,10,11,12]:
      continue

    params_value = {
        "type": "apbd",
        "provinsi": provinsi[0],
        "periode": periode[0],
        "tahun": tahun[0],
        "pemda": "--",
    }

    print(provinsi[1], periode[1], tahun[1])

    # Construct filename
    filename = f"apbd_{provinsi[1]}_{periode[1]}_{tahun[1]}.xlsx"
    filepath = os.path.join("apbd_excels", filename)

    try:
      print(f"Downloading {filename}...")
      r = requests.get(BASE_URL, params=params_value, timeout=60)

      raw = r.content.decode("utf-8", errors="ignore")
      reader = csv.reader(StringIO(raw), delimiter=",", quotechar='"')
      rows = list(reader)

      df = pd.DataFrame(rows[1:], columns=rows[0])  # first row as header

      # Add metadata columns
      df["provinsi"] = provinsi[1]
      df["periode"] = periode[1]
      df["tahun"] = tahun[1]
      df["pemda"] = "Semua Pemda"

      # Append to master dataframe
      all_data = pd.concat([all_data, df], ignore_index=True)

      print(f"✅ Appended {provinsi}-{periode}-{tahun}, rows: {len(df)}")

    except Exception as e:
      print(f"❌ Error parsing CSV for {provinsi}-{periode}-{tahun}: {e}")

# Save final dataframe once
all_data.to_csv("apbd_all.csv", index=False)
print(f"🎉 Final dataframe shape: {all_data.shape}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Provinsi Maluku Desember 2019
# Downloading apbd_Provinsi Maluku_Desember_2019.xlsx...
# ✅ Appended ('25', 'Provinsi Maluku')-('12', 'Desember')-('2019', '2019'), rows: 36
# Progress: 65.789%
# Provinsi Maluku Desember 2018
# Downloading apbd_Provinsi Maluku_Desember_2018.xlsx...
# ✅ Appended ('25', 'Provinsi Maluku')-('12', 'Desember')-('2018', '2018'), rows: 36
# Progress: 65.817%
# Provinsi Papua Januari 2025
# Downloading apbd_Provinsi Papua_Januari_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('1', 'Januari')-('2025', '2025'), rows: 40
# Progress: 65.844%
# Provinsi Papua Januari 2024
# Downloading apbd_Provinsi Papua_Januari_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('1', 'Januari')-('2024', '2024'), rows: 37
# Progress: 65.872%
# Provinsi Papua Januari 2023
# Downloading apbd_Provinsi Papua_Januari_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('1', 'Januari')-('2023', '2023'), rows: 41
# Progress: 65.899%
# Provinsi Papua Januari 2022
# Downloading apbd_Provinsi Papua_Januari_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('1', 'Januari')-('2022', '2022'), rows: 36
# Progress: 65.927%
# Provinsi Papua Januari 2021
# Downloading apbd_Provinsi Papua_Januari_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('1', 'Januari')-('2021', '2021'), rows: 42
# Progress: 65.954%
# Provinsi Papua Januari 2020
# Downloading apbd_Provinsi Papua_Januari_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('1', 'Januari')-('2020', '2020'), rows: 43
# Progress: 65.981%
# Provinsi Papua Januari 2019
# Downloading apbd_Provinsi Papua_Januari_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('1', 'Januari')-('2019', '2019'), rows: 37
# Progress: 66.009%
# Provinsi Papua Januari 2018
# Downloading apbd_Provinsi Papua_Januari_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('1', 'Januari')-('2018', '2018'), rows: 39
# Progress: 66.036%
# Provinsi Papua Februari 2025
# Downloading apbd_Provinsi Papua_Februari_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('2', 'Februari')-('2025', '2025'), rows: 40
# Progress: 66.064%
# Provinsi Papua Februari 2024
# Downloading apbd_Provinsi Papua_Februari_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('2', 'Februari')-('2024', '2024'), rows: 38
# Progress: 66.091%
# Provinsi Papua Februari 2023
# Downloading apbd_Provinsi Papua_Februari_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('2', 'Februari')-('2023', '2023'), rows: 41
# Progress: 66.118%
# Provinsi Papua Februari 2022
# Downloading apbd_Provinsi Papua_Februari_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('2', 'Februari')-('2022', '2022'), rows: 36
# Progress: 66.146%
# Provinsi Papua Februari 2021
# Downloading apbd_Provinsi Papua_Februari_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('2', 'Februari')-('2021', '2021'), rows: 42
# Progress: 66.173%
# Provinsi Papua Februari 2020
# Downloading apbd_Provinsi Papua_Februari_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('2', 'Februari')-('2020', '2020'), rows: 43
# Progress: 66.201%
# Provinsi Papua Februari 2019
# Downloading apbd_Provinsi Papua_Februari_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('2', 'Februari')-('2019', '2019'), rows: 37
# Progress: 66.228%
# Provinsi Papua Februari 2018
# Downloading apbd_Provinsi Papua_Februari_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('2', 'Februari')-('2018', '2018'), rows: 39
# Progress: 66.255%
# Provinsi Papua Maret 2025
# Downloading apbd_Provinsi Papua_Maret_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('3', 'Maret')-('2025', '2025'), rows: 40
# Progress: 66.283%
# Provinsi Papua Maret 2024
# Downloading apbd_Provinsi Papua_Maret_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('3', 'Maret')-('2024', '2024'), rows: 38
# Progress: 66.310%
# Provinsi Papua Maret 2023
# Downloading apbd_Provinsi Papua_Maret_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('3', 'Maret')-('2023', '2023'), rows: 41
# Progress: 66.338%
# Provinsi Papua Maret 2022
# Downloading apbd_Provinsi Papua_Maret_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('3', 'Maret')-('2022', '2022'), rows: 36
# Progress: 66.365%
# Provinsi Papua Maret 2021
# Downloading apbd_Provinsi Papua_Maret_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('3', 'Maret')-('2021', '2021'), rows: 42
# Progress: 66.393%
# Provinsi Papua Maret 2020
# Downloading apbd_Provinsi Papua_Maret_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('3', 'Maret')-('2020', '2020'), rows: 43
# Progress: 66.420%
# Provinsi Papua Maret 2019
# Downloading apbd_Provinsi Papua_Maret_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('3', 'Maret')-('2019', '2019'), rows: 37
# Progress: 66.447%
# Provinsi Papua Maret 2018
# Downloading apbd_Provinsi Papua_Maret_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('3', 'Maret')-('2018', '2018'), rows: 39
# Progress: 66.475%
# Provinsi Papua April 2025
# Downloading apbd_Provinsi Papua_April_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('4', 'April')-('2025', '2025'), rows: 40
# Progress: 66.502%
# Provinsi Papua April 2024
# Downloading apbd_Provinsi Papua_April_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('4', 'April')-('2024', '2024'), rows: 38
# Progress: 66.530%
# Provinsi Papua April 2023
# Downloading apbd_Provinsi Papua_April_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('4', 'April')-('2023', '2023'), rows: 41
# Progress: 66.557%
# Provinsi Papua April 2022
# Downloading apbd_Provinsi Papua_April_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('4', 'April')-('2022', '2022'), rows: 36
# Progress: 66.584%
# Provinsi Papua April 2021
# Downloading apbd_Provinsi Papua_April_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('4', 'April')-('2021', '2021'), rows: 42
# Progress: 66.612%
# Provinsi Papua April 2020
# Downloading apbd_Provinsi Papua_April_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('4', 'April')-('2020', '2020'), rows: 43
# Progress: 66.639%
# Provinsi Papua April 2019
# Downloading apbd_Provinsi Papua_April_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('4', 'April')-('2019', '2019'), rows: 37
# Progress: 66.667%
# Provinsi Papua April 2018
# Downloading apbd_Provinsi Papua_April_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('4', 'April')-('2018', '2018'), rows: 39
# Progress: 66.694%
# Provinsi Papua Mei 2025
# Downloading apbd_Provinsi Papua_Mei_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('5', 'Mei')-('2025', '2025'), rows: 40
# Progress: 66.721%
# Provinsi Papua Mei 2024
# Downloading apbd_Provinsi Papua_Mei_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('5', 'Mei')-('2024', '2024'), rows: 39
# Progress: 66.749%
# Provinsi Papua Mei 2023
# Downloading apbd_Provinsi Papua_Mei_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('5', 'Mei')-('2023', '2023'), rows: 41
# Progress: 66.776%
# Provinsi Papua Mei 2022
# Downloading apbd_Provinsi Papua_Mei_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('5', 'Mei')-('2022', '2022'), rows: 36
# Progress: 66.804%
# Provinsi Papua Mei 2021
# Downloading apbd_Provinsi Papua_Mei_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('5', 'Mei')-('2021', '2021'), rows: 42
# Progress: 66.831%
# Provinsi Papua Mei 2020
# Downloading apbd_Provinsi Papua_Mei_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('5', 'Mei')-('2020', '2020'), rows: 43
# Progress: 66.859%
# Provinsi Papua Mei 2019
# Downloading apbd_Provinsi Papua_Mei_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('5', 'Mei')-('2019', '2019'), rows: 37
# Progress: 66.886%
# Provinsi Papua Mei 2018
# Downloading apbd_Provinsi Papua_Mei_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('5', 'Mei')-('2018', '2018'), rows: 39
# Progress: 66.913%
# Provinsi Papua Juni 2025
# Downloading apbd_Provinsi Papua_Juni_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('6', 'Juni')-('2025', '2025'), rows: 40
# Progress: 66.941%
# Provinsi Papua Juni 2024
# Downloading apbd_Provinsi Papua_Juni_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('6', 'Juni')-('2024', '2024'), rows: 39
# Progress: 66.968%
# Provinsi Papua Juni 2023
# Downloading apbd_Provinsi Papua_Juni_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('6', 'Juni')-('2023', '2023'), rows: 41
# Progress: 66.996%
# Provinsi Papua Juni 2022
# Downloading apbd_Provinsi Papua_Juni_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('6', 'Juni')-('2022', '2022'), rows: 36
# Progress: 67.023%
# Provinsi Papua Juni 2021
# Downloading apbd_Provinsi Papua_Juni_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('6', 'Juni')-('2021', '2021'), rows: 42
# Progress: 67.050%
# Provinsi Papua Juni 2020
# Downloading apbd_Provinsi Papua_Juni_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('6', 'Juni')-('2020', '2020'), rows: 43
# Progress: 67.078%
# Provinsi Papua Juni 2019
# Downloading apbd_Provinsi Papua_Juni_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('6', 'Juni')-('2019', '2019'), rows: 37
# Progress: 67.105%
# Provinsi Papua Juni 2018
# Downloading apbd_Provinsi Papua_Juni_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('6', 'Juni')-('2018', '2018'), rows: 39
# Progress: 67.133%
# Provinsi Papua Juli 2025
# Downloading apbd_Provinsi Papua_Juli_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('7', 'Juli')-('2025', '2025'), rows: 41
# Progress: 67.160%
# Provinsi Papua Juli 2024
# Downloading apbd_Provinsi Papua_Juli_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('7', 'Juli')-('2024', '2024'), rows: 40
# Progress: 67.188%
# Provinsi Papua Juli 2023
# Downloading apbd_Provinsi Papua_Juli_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('7', 'Juli')-('2023', '2023'), rows: 41
# Progress: 67.215%
# Provinsi Papua Juli 2022
# Downloading apbd_Provinsi Papua_Juli_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('7', 'Juli')-('2022', '2022'), rows: 36
# Progress: 67.242%
# Provinsi Papua Juli 2021
# Downloading apbd_Provinsi Papua_Juli_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('7', 'Juli')-('2021', '2021'), rows: 42
# Progress: 67.270%
# Provinsi Papua Juli 2020
# Downloading apbd_Provinsi Papua_Juli_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('7', 'Juli')-('2020', '2020'), rows: 43
# Progress: 67.297%
# Provinsi Papua Juli 2019
# Downloading apbd_Provinsi Papua_Juli_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('7', 'Juli')-('2019', '2019'), rows: 37
# Progress: 67.325%
# Provinsi Papua Juli 2018
# Downloading apbd_Provinsi Papua_Juli_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('7', 'Juli')-('2018', '2018'), rows: 39
# Progress: 67.352%
# Provinsi Papua Agustus 2025
# Downloading apbd_Provinsi Papua_Agustus_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('8', 'Agustus')-('2025', '2025'), rows: 41
# Progress: 67.379%
# Provinsi Papua Agustus 2024
# Downloading apbd_Provinsi Papua_Agustus_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('8', 'Agustus')-('2024', '2024'), rows: 40
# Progress: 67.407%
# Provinsi Papua Agustus 2023
# Downloading apbd_Provinsi Papua_Agustus_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('8', 'Agustus')-('2023', '2023'), rows: 42
# Progress: 67.434%
# Provinsi Papua Agustus 2022
# Downloading apbd_Provinsi Papua_Agustus_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('8', 'Agustus')-('2022', '2022'), rows: 36
# Progress: 67.462%
# Provinsi Papua Agustus 2021
# Downloading apbd_Provinsi Papua_Agustus_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('8', 'Agustus')-('2021', '2021'), rows: 42
# Progress: 67.489%
# Provinsi Papua Agustus 2020
# Downloading apbd_Provinsi Papua_Agustus_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('8', 'Agustus')-('2020', '2020'), rows: 43
# Progress: 67.516%
# Provinsi Papua Agustus 2019
# Downloading apbd_Provinsi Papua_Agustus_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('8', 'Agustus')-('2019', '2019'), rows: 37
# Progress: 67.544%
# Provinsi Papua Agustus 2018
# Downloading apbd_Provinsi Papua_Agustus_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('8', 'Agustus')-('2018', '2018'), rows: 39
# Progress: 67.571%
# Provinsi Papua September 2025
# Downloading apbd_Provinsi Papua_September_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('9', 'September')-('2025', '2025'), rows: 41
# Progress: 67.599%
# Provinsi Papua September 2024
# Downloading apbd_Provinsi Papua_September_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('9', 'September')-('2024', '2024'), rows: 40
# Progress: 67.626%
# Provinsi Papua September 2023
# Downloading apbd_Provinsi Papua_September_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('9', 'September')-('2023', '2023'), rows: 42
# Progress: 67.654%
# Provinsi Papua September 2022
# Downloading apbd_Provinsi Papua_September_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('9', 'September')-('2022', '2022'), rows: 36
# Progress: 67.681%
# Provinsi Papua September 2021
# Downloading apbd_Provinsi Papua_September_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('9', 'September')-('2021', '2021'), rows: 42
# Progress: 67.708%
# Provinsi Papua September 2020
# Downloading apbd_Provinsi Papua_September_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('9', 'September')-('2020', '2020'), rows: 43
# Progress: 67.736%
# Provinsi Papua September 2019
# Downloading apbd_Provinsi Papua_September_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('9', 'September')-('2019', '2019'), rows: 37
# Progress: 67.763%
# Provinsi Papua September 2018
# Downloading apbd_Provinsi Papua_September_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('9', 'September')-('2018', '2018'), rows: 39
# Progress: 67.791%
# Provinsi Papua Oktober 2025
# Downloading apbd_Provinsi Papua_Oktober_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('10', 'Oktober')-('2025', '2025'), rows: 41
# Progress: 67.818%
# Provinsi Papua Oktober 2024
# Downloading apbd_Provinsi Papua_Oktober_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('10', 'Oktober')-('2024', '2024'), rows: 40
# Progress: 67.845%
# Provinsi Papua Oktober 2023
# Downloading apbd_Provinsi Papua_Oktober_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('10', 'Oktober')-('2023', '2023'), rows: 42
# Progress: 67.873%
# Provinsi Papua Oktober 2022
# Downloading apbd_Provinsi Papua_Oktober_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('10', 'Oktober')-('2022', '2022'), rows: 36
# Progress: 67.900%
# Provinsi Papua Oktober 2021
# Downloading apbd_Provinsi Papua_Oktober_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('10', 'Oktober')-('2021', '2021'), rows: 42
# Progress: 67.928%
# Provinsi Papua Oktober 2020
# Downloading apbd_Provinsi Papua_Oktober_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('10', 'Oktober')-('2020', '2020'), rows: 43
# Progress: 67.955%
# Provinsi Papua Oktober 2019
# Downloading apbd_Provinsi Papua_Oktober_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('10', 'Oktober')-('2019', '2019'), rows: 37
# Progress: 67.982%
# Provinsi Papua Oktober 2018
# Downloading apbd_Provinsi Papua_Oktober_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('10', 'Oktober')-('2018', '2018'), rows: 39
# Progress: 68.010%
# Provinsi Papua November 2025
# Downloading apbd_Provinsi Papua_November_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('11', 'November')-('2025', '2025'), rows: 41
# Progress: 68.037%
# Provinsi Papua November 2024
# Downloading apbd_Provinsi Papua_November_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('11', 'November')-('2024', '2024'), rows: 40
# Progress: 68.065%
# Provinsi Papua November 2023
# Downloading apbd_Provinsi Papua_November_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('11', 'November')-('2023', '2023'), rows: 42
# Progress: 68.092%
# Provinsi Papua November 2022
# Downloading apbd_Provinsi Papua_November_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('11', 'November')-('2022', '2022'), rows: 36
# Progress: 68.120%
# Provinsi Papua November 2021
# Downloading apbd_Provinsi Papua_November_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('11', 'November')-('2021', '2021'), rows: 42
# Progress: 68.147%
# Provinsi Papua November 2020
# Downloading apbd_Provinsi Papua_November_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('11', 'November')-('2020', '2020'), rows: 43
# Progress: 68.174%
# Provinsi Papua November 2019
# Downloading apbd_Provinsi Papua_November_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('11', 'November')-('2019', '2019'), rows: 37
# Progress: 68.202%
# Provinsi Papua November 2018
# Downloading apbd_Provinsi Papua_November_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('11', 'November')-('2018', '2018'), rows: 39
# Progress: 68.229%
# Provinsi Papua Desember 2025
# Downloading apbd_Provinsi Papua_Desember_2025.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('12', 'Desember')-('2025', '2025'), rows: 37
# Progress: 68.257%
# Provinsi Papua Desember 2024
# Downloading apbd_Provinsi Papua_Desember_2024.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('12', 'Desember')-('2024', '2024'), rows: 36
# Progress: 68.284%
# Provinsi Papua Desember 2023
# Downloading apbd_Provinsi Papua_Desember_2023.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('12', 'Desember')-('2023', '2023'), rows: 38
# Progress: 68.311%
# Provinsi Papua Desember 2022
# Downloading apbd_Provinsi Papua_Desember_2022.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('12', 'Desember')-('2022', '2022'), rows: 36
# Progress: 68.339%
# Provinsi Papua Desember 2021
# Downloading apbd_Provinsi Papua_Desember_2021.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('12', 'Desember')-('2021', '2021'), rows: 42
# Progress: 68.366%
# Provinsi Papua Desember 2020
# Downloading apbd_Provinsi Papua_Desember_2020.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('12', 'Desember')-('2020', '2020'), rows: 43
# Progress: 68.394%
# Provinsi Papua Desember 2019
# Downloading apbd_Provinsi Papua_Desember_2019.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('12', 'Desember')-('2019', '2019'), rows: 37
# Progress: 68.421%
# Provinsi Papua Desember 2018
# Downloading apbd_Provinsi Papua_Desember_2018.xlsx...
# ✅ Appended ('26', 'Provinsi Papua')-('12', 'Desember')-('2018', '2018'), rows: 39
# Progress: 68.448%
# Provinsi Maluku Utara Januari 2025
# Downloading apbd_Provinsi Maluku Utara_Januari_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('1', 'Januari')-('2025', '2025'), rows: 35
# Progress: 68.476%
# Provinsi Maluku Utara Januari 2024
# Downloading apbd_Provinsi Maluku Utara_Januari_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('1', 'Januari')-('2024', '2024'), rows: 34
# Progress: 68.503%
# Provinsi Maluku Utara Januari 2023
# Downloading apbd_Provinsi Maluku Utara_Januari_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('1', 'Januari')-('2023', '2023'), rows: 36
# Progress: 68.531%
# Provinsi Maluku Utara Januari 2022
# Downloading apbd_Provinsi Maluku Utara_Januari_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('1', 'Januari')-('2022', '2022'), rows: 36
# Progress: 68.558%
# Provinsi Maluku Utara Januari 2021
# Downloading apbd_Provinsi Maluku Utara_Januari_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('1', 'Januari')-('2021', '2021'), rows: 42
# Progress: 68.586%
# Provinsi Maluku Utara Januari 2020
# Downloading apbd_Provinsi Maluku Utara_Januari_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('1', 'Januari')-('2020', '2020'), rows: 43
# Progress: 68.613%
# Provinsi Maluku Utara Januari 2019
# Downloading apbd_Provinsi Maluku Utara_Januari_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('1', 'Januari')-('2019', '2019'), rows: 36
# Progress: 68.640%
# Provinsi Maluku Utara Januari 2018
# Downloading apbd_Provinsi Maluku Utara_Januari_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('1', 'Januari')-('2018', '2018'), rows: 36
# Progress: 68.668%
# Provinsi Maluku Utara Februari 2025
# Downloading apbd_Provinsi Maluku Utara_Februari_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('2', 'Februari')-('2025', '2025'), rows: 35
# Progress: 68.695%
# Provinsi Maluku Utara Februari 2024
# Downloading apbd_Provinsi Maluku Utara_Februari_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('2', 'Februari')-('2024', '2024'), rows: 35
# Progress: 68.723%
# Provinsi Maluku Utara Februari 2023
# Downloading apbd_Provinsi Maluku Utara_Februari_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('2', 'Februari')-('2023', '2023'), rows: 36
# Progress: 68.750%
# Provinsi Maluku Utara Februari 2022
# Downloading apbd_Provinsi Maluku Utara_Februari_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('2', 'Februari')-('2022', '2022'), rows: 36
# Progress: 68.777%
# Provinsi Maluku Utara Februari 2021
# Downloading apbd_Provinsi Maluku Utara_Februari_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('2', 'Februari')-('2021', '2021'), rows: 42
# Progress: 68.805%
# Provinsi Maluku Utara Februari 2020
# Downloading apbd_Provinsi Maluku Utara_Februari_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('2', 'Februari')-('2020', '2020'), rows: 43
# Progress: 68.832%
# Provinsi Maluku Utara Februari 2019
# Downloading apbd_Provinsi Maluku Utara_Februari_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('2', 'Februari')-('2019', '2019'), rows: 36
# Progress: 68.860%
# Provinsi Maluku Utara Februari 2018
# Downloading apbd_Provinsi Maluku Utara_Februari_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('2', 'Februari')-('2018', '2018'), rows: 36
# Progress: 68.887%
# Provinsi Maluku Utara Maret 2025
# Downloading apbd_Provinsi Maluku Utara_Maret_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('3', 'Maret')-('2025', '2025'), rows: 36
# Progress: 68.914%
# Provinsi Maluku Utara Maret 2024
# Downloading apbd_Provinsi Maluku Utara_Maret_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('3', 'Maret')-('2024', '2024'), rows: 35
# Progress: 68.942%
# Provinsi Maluku Utara Maret 2023
# Downloading apbd_Provinsi Maluku Utara_Maret_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('3', 'Maret')-('2023', '2023'), rows: 36
# Progress: 68.969%
# Provinsi Maluku Utara Maret 2022
# Downloading apbd_Provinsi Maluku Utara_Maret_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('3', 'Maret')-('2022', '2022'), rows: 36
# Progress: 68.997%
# Provinsi Maluku Utara Maret 2021
# Downloading apbd_Provinsi Maluku Utara_Maret_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('3', 'Maret')-('2021', '2021'), rows: 42
# Progress: 69.024%
# Provinsi Maluku Utara Maret 2020
# Downloading apbd_Provinsi Maluku Utara_Maret_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('3', 'Maret')-('2020', '2020'), rows: 43
# Progress: 69.052%
# Provinsi Maluku Utara Maret 2019
# Downloading apbd_Provinsi Maluku Utara_Maret_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('3', 'Maret')-('2019', '2019'), rows: 36
# Progress: 69.079%
# Provinsi Maluku Utara Maret 2018
# Downloading apbd_Provinsi Maluku Utara_Maret_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('3', 'Maret')-('2018', '2018'), rows: 36
# Progress: 69.106%
# Provinsi Maluku Utara April 2025
# Downloading apbd_Provinsi Maluku Utara_April_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('4', 'April')-('2025', '2025'), rows: 36
# Progress: 69.134%
# Provinsi Maluku Utara April 2024
# Downloading apbd_Provinsi Maluku Utara_April_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('4', 'April')-('2024', '2024'), rows: 35
# Progress: 69.161%
# Provinsi Maluku Utara April 2023
# Downloading apbd_Provinsi Maluku Utara_April_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('4', 'April')-('2023', '2023'), rows: 36
# Progress: 69.189%
# Provinsi Maluku Utara April 2022
# Downloading apbd_Provinsi Maluku Utara_April_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('4', 'April')-('2022', '2022'), rows: 36
# Progress: 69.216%
# Provinsi Maluku Utara April 2021
# Downloading apbd_Provinsi Maluku Utara_April_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('4', 'April')-('2021', '2021'), rows: 42
# Progress: 69.243%
# Provinsi Maluku Utara April 2020
# Downloading apbd_Provinsi Maluku Utara_April_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('4', 'April')-('2020', '2020'), rows: 43
# Progress: 69.271%
# Provinsi Maluku Utara April 2019
# Downloading apbd_Provinsi Maluku Utara_April_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('4', 'April')-('2019', '2019'), rows: 36
# Progress: 69.298%
# Provinsi Maluku Utara April 2018
# Downloading apbd_Provinsi Maluku Utara_April_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('4', 'April')-('2018', '2018'), rows: 36
# Progress: 69.326%
# Provinsi Maluku Utara Mei 2025
# Downloading apbd_Provinsi Maluku Utara_Mei_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('5', 'Mei')-('2025', '2025'), rows: 36
# Progress: 69.353%
# Provinsi Maluku Utara Mei 2024
# Downloading apbd_Provinsi Maluku Utara_Mei_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('5', 'Mei')-('2024', '2024'), rows: 35
# Progress: 69.380%
# Provinsi Maluku Utara Mei 2023
# Downloading apbd_Provinsi Maluku Utara_Mei_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('5', 'Mei')-('2023', '2023'), rows: 36
# Progress: 69.408%
# Provinsi Maluku Utara Mei 2022
# Downloading apbd_Provinsi Maluku Utara_Mei_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('5', 'Mei')-('2022', '2022'), rows: 36
# Progress: 69.435%
# Provinsi Maluku Utara Mei 2021
# Downloading apbd_Provinsi Maluku Utara_Mei_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('5', 'Mei')-('2021', '2021'), rows: 42
# Progress: 69.463%
# Provinsi Maluku Utara Mei 2020
# Downloading apbd_Provinsi Maluku Utara_Mei_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('5', 'Mei')-('2020', '2020'), rows: 43
# Progress: 69.490%
# Provinsi Maluku Utara Mei 2019
# Downloading apbd_Provinsi Maluku Utara_Mei_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('5', 'Mei')-('2019', '2019'), rows: 36
# Progress: 69.518%
# Provinsi Maluku Utara Mei 2018
# Downloading apbd_Provinsi Maluku Utara_Mei_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('5', 'Mei')-('2018', '2018'), rows: 36
# Progress: 69.545%
# Provinsi Maluku Utara Juni 2025
# Downloading apbd_Provinsi Maluku Utara_Juni_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('6', 'Juni')-('2025', '2025'), rows: 36
# Progress: 69.572%
# Provinsi Maluku Utara Juni 2024
# Downloading apbd_Provinsi Maluku Utara_Juni_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('6', 'Juni')-('2024', '2024'), rows: 35
# Progress: 69.600%
# Provinsi Maluku Utara Juni 2023
# Downloading apbd_Provinsi Maluku Utara_Juni_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('6', 'Juni')-('2023', '2023'), rows: 36
# Progress: 69.627%
# Provinsi Maluku Utara Juni 2022
# Downloading apbd_Provinsi Maluku Utara_Juni_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('6', 'Juni')-('2022', '2022'), rows: 36
# Progress: 69.655%
# Provinsi Maluku Utara Juni 2021
# Downloading apbd_Provinsi Maluku Utara_Juni_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('6', 'Juni')-('2021', '2021'), rows: 42
# Progress: 69.682%
# Provinsi Maluku Utara Juni 2020
# Downloading apbd_Provinsi Maluku Utara_Juni_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('6', 'Juni')-('2020', '2020'), rows: 43
# Progress: 69.709%
# Provinsi Maluku Utara Juni 2019
# Downloading apbd_Provinsi Maluku Utara_Juni_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('6', 'Juni')-('2019', '2019'), rows: 36
# Progress: 69.737%
# Provinsi Maluku Utara Juni 2018
# Downloading apbd_Provinsi Maluku Utara_Juni_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('6', 'Juni')-('2018', '2018'), rows: 36
# Progress: 69.764%
# Provinsi Maluku Utara Juli 2025
# Downloading apbd_Provinsi Maluku Utara_Juli_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('7', 'Juli')-('2025', '2025'), rows: 36
# Progress: 69.792%
# Provinsi Maluku Utara Juli 2024
# Downloading apbd_Provinsi Maluku Utara_Juli_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('7', 'Juli')-('2024', '2024'), rows: 35
# Progress: 69.819%
# Provinsi Maluku Utara Juli 2023
# Downloading apbd_Provinsi Maluku Utara_Juli_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('7', 'Juli')-('2023', '2023'), rows: 36
# Progress: 69.846%
# Provinsi Maluku Utara Juli 2022
# Downloading apbd_Provinsi Maluku Utara_Juli_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('7', 'Juli')-('2022', '2022'), rows: 36
# Progress: 69.874%
# Provinsi Maluku Utara Juli 2021
# Downloading apbd_Provinsi Maluku Utara_Juli_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('7', 'Juli')-('2021', '2021'), rows: 42
# Progress: 69.901%
# Provinsi Maluku Utara Juli 2020
# Downloading apbd_Provinsi Maluku Utara_Juli_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('7', 'Juli')-('2020', '2020'), rows: 43
# Progress: 69.929%
# Provinsi Maluku Utara Juli 2019
# Downloading apbd_Provinsi Maluku Utara_Juli_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('7', 'Juli')-('2019', '2019'), rows: 36
# Progress: 69.956%
# Provinsi Maluku Utara Juli 2018
# Downloading apbd_Provinsi Maluku Utara_Juli_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('7', 'Juli')-('2018', '2018'), rows: 36
# Progress: 69.984%
# Provinsi Maluku Utara Agustus 2025
# Downloading apbd_Provinsi Maluku Utara_Agustus_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('8', 'Agustus')-('2025', '2025'), rows: 36
# Progress: 70.011%
# Provinsi Maluku Utara Agustus 2024
# Downloading apbd_Provinsi Maluku Utara_Agustus_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('8', 'Agustus')-('2024', '2024'), rows: 35
# Progress: 70.038%
# Provinsi Maluku Utara Agustus 2023
# Downloading apbd_Provinsi Maluku Utara_Agustus_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('8', 'Agustus')-('2023', '2023'), rows: 36
# Progress: 70.066%
# Provinsi Maluku Utara Agustus 2022
# Downloading apbd_Provinsi Maluku Utara_Agustus_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('8', 'Agustus')-('2022', '2022'), rows: 36
# Progress: 70.093%
# Provinsi Maluku Utara Agustus 2021
# Downloading apbd_Provinsi Maluku Utara_Agustus_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('8', 'Agustus')-('2021', '2021'), rows: 42
# Progress: 70.121%
# Provinsi Maluku Utara Agustus 2020
# Downloading apbd_Provinsi Maluku Utara_Agustus_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('8', 'Agustus')-('2020', '2020'), rows: 43
# Progress: 70.148%
# Provinsi Maluku Utara Agustus 2019
# Downloading apbd_Provinsi Maluku Utara_Agustus_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('8', 'Agustus')-('2019', '2019'), rows: 36
# Progress: 70.175%
# Provinsi Maluku Utara Agustus 2018
# Downloading apbd_Provinsi Maluku Utara_Agustus_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('8', 'Agustus')-('2018', '2018'), rows: 36
# Progress: 70.203%
# Provinsi Maluku Utara September 2025
# Downloading apbd_Provinsi Maluku Utara_September_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('9', 'September')-('2025', '2025'), rows: 36
# Progress: 70.230%
# Provinsi Maluku Utara September 2024
# Downloading apbd_Provinsi Maluku Utara_September_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('9', 'September')-('2024', '2024'), rows: 35
# Progress: 70.258%
# Provinsi Maluku Utara September 2023
# Downloading apbd_Provinsi Maluku Utara_September_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('9', 'September')-('2023', '2023'), rows: 36
# Progress: 70.285%
# Provinsi Maluku Utara September 2022
# Downloading apbd_Provinsi Maluku Utara_September_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('9', 'September')-('2022', '2022'), rows: 36
# Progress: 70.312%
# Provinsi Maluku Utara September 2021
# Downloading apbd_Provinsi Maluku Utara_September_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('9', 'September')-('2021', '2021'), rows: 42
# Progress: 70.340%
# Provinsi Maluku Utara September 2020
# Downloading apbd_Provinsi Maluku Utara_September_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('9', 'September')-('2020', '2020'), rows: 43
# Progress: 70.367%
# Provinsi Maluku Utara September 2019
# Downloading apbd_Provinsi Maluku Utara_September_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('9', 'September')-('2019', '2019'), rows: 36
# Progress: 70.395%
# Provinsi Maluku Utara September 2018
# Downloading apbd_Provinsi Maluku Utara_September_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('9', 'September')-('2018', '2018'), rows: 36
# Progress: 70.422%
# Provinsi Maluku Utara Oktober 2025
# Downloading apbd_Provinsi Maluku Utara_Oktober_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('10', 'Oktober')-('2025', '2025'), rows: 36
# Progress: 70.450%
# Provinsi Maluku Utara Oktober 2024
# Downloading apbd_Provinsi Maluku Utara_Oktober_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('10', 'Oktober')-('2024', '2024'), rows: 35
# Progress: 70.477%
# Provinsi Maluku Utara Oktober 2023
# Downloading apbd_Provinsi Maluku Utara_Oktober_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('10', 'Oktober')-('2023', '2023'), rows: 36
# Progress: 70.504%
# Provinsi Maluku Utara Oktober 2022
# Downloading apbd_Provinsi Maluku Utara_Oktober_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('10', 'Oktober')-('2022', '2022'), rows: 36
# Progress: 70.532%
# Provinsi Maluku Utara Oktober 2021
# Downloading apbd_Provinsi Maluku Utara_Oktober_2021.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('10', 'Oktober')-('2021', '2021'), rows: 42
# Progress: 70.559%
# Provinsi Maluku Utara Oktober 2020
# Downloading apbd_Provinsi Maluku Utara_Oktober_2020.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('10', 'Oktober')-('2020', '2020'), rows: 43
# Progress: 70.587%
# Provinsi Maluku Utara Oktober 2019
# Downloading apbd_Provinsi Maluku Utara_Oktober_2019.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('10', 'Oktober')-('2019', '2019'), rows: 36
# Progress: 70.614%
# Provinsi Maluku Utara Oktober 2018
# Downloading apbd_Provinsi Maluku Utara_Oktober_2018.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('10', 'Oktober')-('2018', '2018'), rows: 36
# Progress: 70.641%
# Provinsi Maluku Utara November 2025
# Downloading apbd_Provinsi Maluku Utara_November_2025.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('11', 'November')-('2025', '2025'), rows: 36
# Progress: 70.669%
# Provinsi Maluku Utara November 2024
# Downloading apbd_Provinsi Maluku Utara_November_2024.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('11', 'November')-('2024', '2024'), rows: 35
# Progress: 70.696%
# Provinsi Maluku Utara November 2023
# Downloading apbd_Provinsi Maluku Utara_November_2023.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-('11', 'November')-('2023', '2023'), rows: 36
# Progress: 70.724%
# Provinsi Maluku Utara November 2022
# Downloading apbd_Provinsi Maluku Utara_November_2022.xlsx...
# ✅ Appended ('27', 'Provinsi Maluku Utara')-
xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('3', 'Maret')-('2018', '2018'), rows: 31
# Progress: 71.738%
# Provinsi Banten April 2025
# Downloading apbd_Provinsi Banten_April_2025.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('4', 'April')-('2025', '2025'), rows: 37
# Progress: 71.765%
# Provinsi Banten April 2024
# Downloading apbd_Provinsi Banten_April_2024.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('4', 'April')-('2024', '2024'), rows: 38
# Progress: 71.793%
# Provinsi Banten April 2023
# Downloading apbd_Provinsi Banten_April_2023.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('4', 'April')-('2023', '2023'), rows: 39
# Progress: 71.820%
# Provinsi Banten April 2022
# Downloading apbd_Provinsi Banten_April_2022.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('4', 'April')-('2022', '2022'), rows: 35
# Progress: 71.848%
# Provinsi Banten April 2021
# Downloading apbd_Provinsi Banten_April_2021.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('4', 'April')-('2021', '2021'), rows: 42
# Progress: 71.875%
# Provinsi Banten April 2020
# Downloading apbd_Provinsi Banten_April_2020.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('4', 'April')-('2020', '2020'), rows: 43
# Progress: 71.902%
# Provinsi Banten April 2019
# Downloading apbd_Provinsi Banten_April_2019.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('4', 'April')-('2019', '2019'), rows: 34
# Progress: 71.930%
# Provinsi Banten April 2018
# Downloading apbd_Provinsi Banten_April_2018.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('4', 'April')-('2018', '2018'), rows: 31
# Progress: 71.957%
# Provinsi Banten Mei 2025
# Downloading apbd_Provinsi Banten_Mei_2025.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('5', 'Mei')-('2025', '2025'), rows: 38
# Progress: 71.985%
# Provinsi Banten Mei 2024
# Downloading apbd_Provinsi Banten_Mei_2024.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('5', 'Mei')-('2024', '2024'), rows: 39
# Progress: 72.012%
# Provinsi Banten Mei 2023
# Downloading apbd_Provinsi Banten_Mei_2023.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('5', 'Mei')-('2023', '2023'), rows: 39
# Progress: 72.039%
# Provinsi Banten Mei 2022
# Downloading apbd_Provinsi Banten_Mei_2022.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('5', 'Mei')-('2022', '2022'), rows: 35
# Progress: 72.067%
# Provinsi Banten Mei 2021
# Downloading apbd_Provinsi Banten_Mei_2021.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('5', 'Mei')-('2021', '2021'), rows: 42
# Progress: 72.094%
# Provinsi Banten Mei 2020
# Downloading apbd_Provinsi Banten_Mei_2020.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('5', 'Mei')-('2020', '2020'), rows: 43
# Progress: 72.122%
# Provinsi Banten Mei 2019
# Downloading apbd_Provinsi Banten_Mei_2019.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('5', 'Mei')-('2019', '2019'), rows: 34
# Progress: 72.149%
# Provinsi Banten Mei 2018
# Downloading apbd_Provinsi Banten_Mei_2018.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('5', 'Mei')-('2018', '2018'), rows: 31
# Progress: 72.177%
# Provinsi Banten Juni 2025
# Downloading apbd_Provinsi Banten_Juni_2025.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('6', 'Juni')-('2025', '2025'), rows: 38
# Progress: 72.204%
# Provinsi Banten Juni 2024
# Downloading apbd_Provinsi Banten_Juni_2024.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('6', 'Juni')-('2024', '2024'), rows: 40
# Progress: 72.231%
# Provinsi Banten Juni 2023
# Downloading apbd_Provinsi Banten_Juni_2023.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('6', 'Juni')-('2023', '2023'), rows: 39
# Progress: 72.259%
# Provinsi Banten Juni 2022
# Downloading apbd_Provinsi Banten_Juni_2022.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('6', 'Juni')-('2022', '2022'), rows: 35
# Progress: 72.286%
# Provinsi Banten Juni 2021
# Downloading apbd_Provinsi Banten_Juni_2021.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('6', 'Juni')-('2021', '2021'), rows: 42
# Progress: 72.314%
# Provinsi Banten Juni 2020
# Downloading apbd_Provinsi Banten_Juni_2020.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('6', 'Juni')-('2020', '2020'), rows: 43
# Progress: 72.341%
# Provinsi Banten Juni 2019
# Downloading apbd_Provinsi Banten_Juni_2019.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('6', 'Juni')-('2019', '2019'), rows: 34
# Progress: 72.368%
# Provinsi Banten Juni 2018
# Downloading apbd_Provinsi Banten_Juni_2018.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('6', 'Juni')-('2018', '2018'), rows: 31
# Progress: 72.396%
# Provinsi Banten Juli 2025
# Downloading apbd_Provinsi Banten_Juli_2025.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('7', 'Juli')-('2025', '2025'), rows: 38
# Progress: 72.423%
# Provinsi Banten Juli 2024
# Downloading apbd_Provinsi Banten_Juli_2024.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('7', 'Juli')-('2024', '2024'), rows: 40
# Progress: 72.451%
# Provinsi Banten Juli 2023
# Downloading apbd_Provinsi Banten_Juli_2023.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('7', 'Juli')-('2023', '2023'), rows: 39
# Progress: 72.478%
# Provinsi Banten Juli 2022
# Downloading apbd_Provinsi Banten_Juli_2022.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('7', 'Juli')-('2022', '2022'), rows: 35
# Progress: 72.505%
# Provinsi Banten Juli 2021
# Downloading apbd_Provinsi Banten_Juli_2021.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('7', 'Juli')-('2021', '2021'), rows: 42
# Progress: 72.533%
# Provinsi Banten Juli 2020
# Downloading apbd_Provinsi Banten_Juli_2020.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('7', 'Juli')-('2020', '2020'), rows: 43
# Progress: 72.560%
# Provinsi Banten Juli 2019
# Downloading apbd_Provinsi Banten_Juli_2019.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('7', 'Juli')-('2019', '2019'), rows: 34
# Progress: 72.588%
# Provinsi Banten Juli 2018
# Downloading apbd_Provinsi Banten_Juli_2018.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('7', 'Juli')-('2018', '2018'), rows: 31
# Progress: 72.615%
# Provinsi Banten Agustus 2025
# Downloading apbd_Provinsi Banten_Agustus_2025.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('8', 'Agustus')-('2025', '2025'), rows: 38
# Progress: 72.643%
# Provinsi Banten Agustus 2024
# Downloading apbd_Provinsi Banten_Agustus_2024.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('8', 'Agustus')-('2024', '2024'), rows: 40
# Progress: 72.670%
# Provinsi Banten Agustus 2023
# Downloading apbd_Provinsi Banten_Agustus_2023.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('8', 'Agustus')-('2023', '2023'), rows: 39
# Progress: 72.697%
# Provinsi Banten Agustus 2022
# Downloading apbd_Provinsi Banten_Agustus_2022.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('8', 'Agustus')-('2022', '2022'), rows: 35
# Progress: 72.725%
# Provinsi Banten Agustus 2021
# Downloading apbd_Provinsi Banten_Agustus_2021.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('8', 'Agustus')-('2021', '2021'), rows: 42
# Progress: 72.752%
# Provinsi Banten Agustus 2020
# Downloading apbd_Provinsi Banten_Agustus_2020.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('8', 'Agustus')-('2020', '2020'), rows: 43
# Progress: 72.780%
# Provinsi Banten Agustus 2019
# Downloading apbd_Provinsi Banten_Agustus_2019.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('8', 'Agustus')-('2019', '2019'), rows: 34
# Progress: 72.807%
# Provinsi Banten Agustus 2018
# Downloading apbd_Provinsi Banten_Agustus_2018.xlsx...
# ✅ Appended ('28', 'Provinsi Banten')-('8', 'Agustus')-('2018', '2018'), rows: 31
# Progress: 72.834%
# Provinsi Banten September 2025
# Downloading apbd_Provinsi Banten_September_2025.xlsx...
# ...
# Progress: 98.218%
# Provinsi Papua Barat Daya April 2019
# Downloading apbd_Provinsi Papua Barat Daya_April_2019.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('4', 'April')-('2019', '2019'): 4 columns passed, passed data had 111 columns
# Progress: 98.246%
# Provinsi Papua Barat Daya April 2018
# Downloading apbd_Provinsi Papua Barat Daya_April_2018.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('4', 'April')-('2018', '2018'): 4 columns passed, passed data had 111 columns
# Progress: 98.273%
# Provinsi Papua Barat Daya Mei 2025
# Downloading apbd_Provinsi Papua Barat Daya_Mei_2025.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('5', 'Mei')-('2025', '2025'), rows: 33
# Progress: 98.300%
# Provinsi Papua Barat Daya Mei 2024
# Downloading apbd_Provinsi Papua Barat Daya_Mei_2024.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('5', 'Mei')-('2024', '2024'), rows: 35
# Progress: 98.328%
# Provinsi Papua Barat Daya Mei 2023
# Downloading apbd_Provinsi Papua Barat Daya_Mei_2023.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('5', 'Mei')-('2023', '2023'), rows: 34
# Progress: 98.355%
# Provinsi Papua Barat Daya Mei 2022
# Downloading apbd_Provinsi Papua Barat Daya_Mei_2022.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('5', 'Mei')-('2022', '2022'): 4 columns passed, passed data had 111 columns
# Progress: 98.383%
# Provinsi Papua Barat Daya Mei 2021
# Downloading apbd_Provinsi Papua Barat Daya_Mei_2021.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('5', 'Mei')-('2021', '2021'): 4 columns passed, passed data had 111 columns
# Progress: 98.410%
# Provinsi Papua Barat Daya Mei 2020
# Downloading apbd_Provinsi Papua Barat Daya_Mei_2020.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('5', 'Mei')-('2020', '2020'): 4 columns passed, passed data had 111 columns
# Progress: 98.438%
# Provinsi Papua Barat Daya Mei 2019
# Downloading apbd_Provinsi Papua Barat Daya_Mei_2019.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('5', 'Mei')-('2019', '2019'): 4 columns passed, passed data had 111 columns
# Progress: 98.465%
# Provinsi Papua Barat Daya Mei 2018
# Downloading apbd_Provinsi Papua Barat Daya_Mei_2018.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('5', 'Mei')-('2018', '2018'): 4 columns passed, passed data had 111 columns
# Progress: 98.492%
# Provinsi Papua Barat Daya Juni 2025
# Downloading apbd_Provinsi Papua Barat Daya_Juni_2025.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('6', 'Juni')-('2025', '2025'), rows: 33
# Progress: 98.520%
# Provinsi Papua Barat Daya Juni 2024
# Downloading apbd_Provinsi Papua Barat Daya_Juni_2024.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('6', 'Juni')-('2024', '2024'), rows: 35
# Progress: 98.547%
# Provinsi Papua Barat Daya Juni 2023
# Downloading apbd_Provinsi Papua Barat Daya_Juni_2023.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('6', 'Juni')-('2023', '2023'), rows: 35
# Progress: 98.575%
# Provinsi Papua Barat Daya Juni 2022
# Downloading apbd_Provinsi Papua Barat Daya_Juni_2022.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('6', 'Juni')-('2022', '2022'): 4 columns passed, passed data had 111 columns
# Progress: 98.602%
# Provinsi Papua Barat Daya Juni 2021
# Downloading apbd_Provinsi Papua Barat Daya_Juni_2021.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('6', 'Juni')-('2021', '2021'): 4 columns passed, passed data had 111 columns
# Progress: 98.629%
# Provinsi Papua Barat Daya Juni 2020
# Downloading apbd_Provinsi Papua Barat Daya_Juni_2020.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('6', 'Juni')-('2020', '2020'): 4 columns passed, passed data had 111 columns
# Progress: 98.657%
# Provinsi Papua Barat Daya Juni 2019
# Downloading apbd_Provinsi Papua Barat Daya_Juni_2019.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('6', 'Juni')-('2019', '2019'): 4 columns passed, passed data had 111 columns
# Progress: 98.684%
# Provinsi Papua Barat Daya Juni 2018
# Downloading apbd_Provinsi Papua Barat Daya_Juni_2018.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('6', 'Juni')-('2018', '2018'): 4 columns passed, passed data had 111 columns
# Progress: 98.712%
# Provinsi Papua Barat Daya Juli 2025
# Downloading apbd_Provinsi Papua Barat Daya_Juli_2025.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('7', 'Juli')-('2025', '2025'), rows: 33
# Progress: 98.739%
# Provinsi Papua Barat Daya Juli 2024
# Downloading apbd_Provinsi Papua Barat Daya_Juli_2024.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('7', 'Juli')-('2024', '2024'), rows: 35
# Progress: 98.766%
# Provinsi Papua Barat Daya Juli 2023
# Downloading apbd_Provinsi Papua Barat Daya_Juli_2023.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('7', 'Juli')-('2023', '2023'), rows: 35
# Progress: 98.794%
# Provinsi Papua Barat Daya Juli 2022
# Downloading apbd_Provinsi Papua Barat Daya_Juli_2022.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('7', 'Juli')-('2022', '2022'): 4 columns passed, passed data had 111 columns
# Progress: 98.821%
# Provinsi Papua Barat Daya Juli 2021
# Downloading apbd_Provinsi Papua Barat Daya_Juli_2021.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('7', 'Juli')-('2021', '2021'): 4 columns passed, passed data had 111 columns
# Progress: 98.849%
# Provinsi Papua Barat Daya Juli 2020
# Downloading apbd_Provinsi Papua Barat Daya_Juli_2020.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('7', 'Juli')-('2020', '2020'): 4 columns passed, passed data had 111 columns
# Progress: 98.876%
# Provinsi Papua Barat Daya Juli 2019
# Downloading apbd_Provinsi Papua Barat Daya_Juli_2019.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('7', 'Juli')-('2019', '2019'): 4 columns passed, passed data had 111 columns
# Progress: 98.904%
# Provinsi Papua Barat Daya Juli 2018
# Downloading apbd_Provinsi Papua Barat Daya_Juli_2018.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('7', 'Juli')-('2018', '2018'): 4 columns passed, passed data had 111 columns
# Progress: 98.931%
# Provinsi Papua Barat Daya Agustus 2025
# Downloading apbd_Provinsi Papua Barat Daya_Agustus_2025.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('8', 'Agustus')-('2025', '2025'), rows: 33
# Progress: 98.958%
# Provinsi Papua Barat Daya Agustus 2024
# Downloading apbd_Provinsi Papua Barat Daya_Agustus_2024.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('8', 'Agustus')-('2024', '2024'), rows: 35
# Progress: 98.986%
# Provinsi Papua Barat Daya Agustus 2023
# Downloading apbd_Provinsi Papua Barat Daya_Agustus_2023.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('8', 'Agustus')-('2023', '2023'), rows: 35
# Progress: 99.013%
# Provinsi Papua Barat Daya Agustus 2022
# Downloading apbd_Provinsi Papua Barat Daya_Agustus_2022.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('8', 'Agustus')-('2022', '2022'): 4 columns passed, passed data had 111 columns
# Progress: 99.041%
# Provinsi Papua Barat Daya Agustus 2021
# Downloading apbd_Provinsi Papua Barat Daya_Agustus_2021.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('8', 'Agustus')-('2021', '2021'): 4 columns passed, passed data had 111 columns
# Progress: 99.068%
# Provinsi Papua Barat Daya Agustus 2020
# Downloading apbd_Provinsi Papua Barat Daya_Agustus_2020.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('8', 'Agustus')-('2020', '2020'): 4 columns passed, passed data had 111 columns
# Progress: 99.095%
# Provinsi Papua Barat Daya Agustus 2019
# Downloading apbd_Provinsi Papua Barat Daya_Agustus_2019.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('8', 'Agustus')-('2019', '2019'): 4 columns passed, passed data had 111 columns
# Progress: 99.123%
# Provinsi Papua Barat Daya Agustus 2018
# Downloading apbd_Provinsi Papua Barat Daya_Agustus_2018.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('8', 'Agustus')-('2018', '2018'): 4 columns passed, passed data had 111 columns
# Progress: 99.150%
# Provinsi Papua Barat Daya September 2025
# Downloading apbd_Provinsi Papua Barat Daya_September_2025.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('9', 'September')-('2025', '2025'), rows: 33
# Progress: 99.178%
# Provinsi Papua Barat Daya September 2024
# Downloading apbd_Provinsi Papua Barat Daya_September_2024.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('9', 'September')-('2024', '2024'), rows: 35
# Progress: 99.205%
# Provinsi Papua Barat Daya September 2023
# Downloading apbd_Provinsi Papua Barat Daya_September_2023.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('9', 'September')-('2023', '2023'), rows: 35
# Progress: 99.232%
# Provinsi Papua Barat Daya September 2022
# Downloading apbd_Provinsi Papua Barat Daya_September_2022.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('9', 'September')-('2022', '2022'): 4 columns passed, passed data had 111 columns
# Progress: 99.260%
# Provinsi Papua Barat Daya September 2021
# Downloading apbd_Provinsi Papua Barat Daya_September_2021.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('9', 'September')-('2021', '2021'): 4 columns passed, passed data had 111 columns
# Progress: 99.287%
# Provinsi Papua Barat Daya September 2020
# Downloading apbd_Provinsi Papua Barat Daya_September_2020.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('9', 'September')-('2020', '2020'): 4 columns passed, passed data had 111 columns
# Progress: 99.315%
# Provinsi Papua Barat Daya September 2019
# Downloading apbd_Provinsi Papua Barat Daya_September_2019.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('9', 'September')-('2019', '2019'): 4 columns passed, passed data had 111 columns
# Progress: 99.342%
# Provinsi Papua Barat Daya September 2018
# Downloading apbd_Provinsi Papua Barat Daya_September_2018.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('9', 'September')-('2018', '2018'): 4 columns passed, passed data had 111 columns
# Progress: 99.370%
# Provinsi Papua Barat Daya Oktober 2025
# Downloading apbd_Provinsi Papua Barat Daya_Oktober_2025.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('10', 'Oktober')-('2025', '2025'), rows: 33
# Progress: 99.397%
# Provinsi Papua Barat Daya Oktober 2024
# Downloading apbd_Provinsi Papua Barat Daya_Oktober_2024.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('10', 'Oktober')-('2024', '2024'), rows: 35
# Progress: 99.424%
# Provinsi Papua Barat Daya Oktober 2023
# Downloading apbd_Provinsi Papua Barat Daya_Oktober_2023.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('10', 'Oktober')-('2023', '2023'), rows: 35
# Progress: 99.452%
# Provinsi Papua Barat Daya Oktober 2022
# Downloading apbd_Provinsi Papua Barat Daya_Oktober_2022.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('10', 'Oktober')-('2022', '2022'): 4 columns passed, passed data had 111 columns
# Progress: 99.479%
# Provinsi Papua Barat Daya Oktober 2021
# Downloading apbd_Provinsi Papua Barat Daya_Oktober_2021.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('10', 'Oktober')-('2021', '2021'): 4 columns passed, passed data had 111 columns
# Progress: 99.507%
# Provinsi Papua Barat Daya Oktober 2020
# Downloading apbd_Provinsi Papua Barat Daya_Oktober_2020.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('10', 'Oktober')-('2020', '2020'): 4 columns passed, passed data had 111 columns
# Progress: 99.534%
# Provinsi Papua Barat Daya Oktober 2019
# Downloading apbd_Provinsi Papua Barat Daya_Oktober_2019.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('10', 'Oktober')-('2019', '2019'): 4 columns passed, passed data had 111 columns
# Progress: 99.561%
# Provinsi Papua Barat Daya Oktober 2018
# Downloading apbd_Provinsi Papua Barat Daya_Oktober_2018.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('10', 'Oktober')-('2018', '2018'): 4 columns passed, passed data had 111 columns
# Progress: 99.589%
# Provinsi Papua Barat Daya November 2025
# Downloading apbd_Provinsi Papua Barat Daya_November_2025.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('11', 'November')-('2025', '2025'), rows: 33
# Progress: 99.616%
# Provinsi Papua Barat Daya November 2024
# Downloading apbd_Provinsi Papua Barat Daya_November_2024.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('11', 'November')-('2024', '2024'), rows: 35
# Progress: 99.644%
# Provinsi Papua Barat Daya November 2023
# Downloading apbd_Provinsi Papua Barat Daya_November_2023.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('11', 'November')-('2023', '2023'), rows: 35
# Progress: 99.671%
# Provinsi Papua Barat Daya November 2022
# Downloading apbd_Provinsi Papua Barat Daya_November_2022.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('11', 'November')-('2022', '2022'): 4 columns passed, passed data had 111 columns
# Progress: 99.698%
# Provinsi Papua Barat Daya November 2021
# Downloading apbd_Provinsi Papua Barat Daya_November_2021.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('11', 'November')-('2021', '2021'): 4 columns passed, passed data had 111 columns
# Progress: 99.726%
# Provinsi Papua Barat Daya November 2020
# Downloading apbd_Provinsi Papua Barat Daya_November_2020.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('11', 'November')-('2020', '2020'): 4 columns passed, passed data had 111 columns
# Progress: 99.753%
# Provinsi Papua Barat Daya November 2019
# Downloading apbd_Provinsi Papua Barat Daya_November_2019.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('11', 'November')-('2019', '2019'): 4 columns passed, passed data had 111 columns
# Progress: 99.781%
# Provinsi Papua Barat Daya November 2018
# Downloading apbd_Provinsi Papua Barat Daya_November_2018.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('11', 'November')-('2018', '2018'): 4 columns passed, passed data had 111 columns
# Progress: 99.808%
# Provinsi Papua Barat Daya Desember 2025
# Downloading apbd_Provinsi Papua Barat Daya_Desember_2025.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('12', 'Desember')-('2025', '2025'), rows: 32
# Progress: 99.836%
# Provinsi Papua Barat Daya Desember 2024
# Downloading apbd_Provinsi Papua Barat Daya_Desember_2024.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('12', 'Desember')-('2024', '2024'), rows: 33
# Progress: 99.863%
# Provinsi Papua Barat Daya Desember 2023
# Downloading apbd_Provinsi Papua Barat Daya_Desember_2023.xlsx...
# ✅ Appended ('38', 'Provinsi Papua Barat Daya')-('12', 'Desember')-('2023', '2023'), rows: 33
# Progress: 99.890%
# Provinsi Papua Barat Daya Desember 2022
# Downloading apbd_Provinsi Papua Barat Daya_Desember_2022.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('12', 'Desember')-('2022', '2022'): 4 columns passed, passed data had 111 columns
# Progress: 99.918%
# Provinsi Papua Barat Daya Desember 2021
# Downloading apbd_Provinsi Papua Barat Daya_Desember_2021.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('12', 'Desember')-('2021', '2021'): 4 columns passed, passed data had 111 columns
# Progress: 99.945%
# Provinsi Papua Barat Daya Desember 2020
# Downloading apbd_Provinsi Papua Barat Daya_Desember_2020.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('12', 'Desember')-('2020', '2020'): 4 columns passed, passed data had 111 columns
# Progress: 99.973%
# Provinsi Papua Barat Daya Desember 2019
# Downloading apbd_Provinsi Papua Barat Daya_Desember_2019.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('12', 'Desember')-('2019', '2019'): 4 columns passed, passed data had 111 columns
# Progress: 100.000%
# Provinsi Papua Barat Daya Desember 2018
# Downloading apbd_Provinsi Papua Barat Daya_Desember_2018.xlsx...
# ❌ Error parsing CSV for ('38', 'Provinsi Papua Barat Daya')-('12', 'Desember')-('2018', '2018'): 4 columns passed, passed data had 111 columns
# 🎉 Final dataframe shape: (129061, 8)

# %%
all_data
# Out:
#                                                      akun     anggaran  \
# 0                                       Pendapatan Daerah  40.039,55 M
# 1                                                     PAD   6.455,14 M
# 2                                            Pajak Daerah   2.716,15 M
# 3                                        Retribusi Daerah   1.084,92 M
# 4        Hasil Pengelolaan Kekayaan Daerah yang Dipisa...     371,97 M
# ...                                                   ...          ...
# 129056                       Penerimaan Pembiayaan Daerah     183,19 M
# 129057   Sisa Lebih Perhitungan Anggaran Tahun Sebelumnya     183,19 M
# 129058                      Pengeluaran Pembiayaan Daerah     172,13 M
# 129059                            Penyertaan Modal Daerah      10,26 M
# 129060    Pembayaran Cicilan Pokok Utang yang Jatuh Tempo     161,87 M
#
#          realisasi persentase                   provinsi   periode tahun  \
# 0       2.789,22 M       6.97              Provinsi Aceh   Januari  2025
# 1         374,43 M       5.80              Provinsi Aceh   Januari  2025
# 2         169,46 M       6.24              Provinsi Aceh   Januari  2025
# 3          85,98 M       7.92              Provinsi Aceh   Januari  2025
# 4           0,00 M       0.00              Provinsi Aceh   Januari  2025
# ...            ...        ...                        ...       ...   ...
# 129056    446,66 M     243.82  Provinsi Papua Barat Daya  Desember  2023
# 129057    446,66 M     243.82  Provinsi Papua Barat Daya  Desember  2023
# 129058    141,67 M      82.30  Provinsi Papua Barat Daya  Desember  2023
# 129059      8,41 M      82.01  Provinsi Papua Barat Daya  Desember  2023
# 129060    133,26 M      82.32  Provinsi Papua Barat Daya  Desember  2023
#
#               pemda
# 0       Semua Pemda
# 1       Semua Pemda
# 2       Semua Pemda
# 3       Semua Pemda
# 4       Semua Pemda
# ...             ...
# 129056  Semua Pemda
# 129057  Semua Pemda
# 129058  Semua Pemda
# 129059  Semua Pemda
# 129060  Semua Pemda
#
# [129061 rows x 8 columns]

# %% [markdown]
# # Scrape pemda-level APBD in Bali

# %%
import requests
from bs4 import BeautifulSoup

url_bali = "https://djpk.kemenkeu.go.id/portal/data/apbd?periode=9&tahun=2025&provinsi=22&pemda=00" # Bali
r = requests.get(url_bali)
soup = BeautifulSoup(r.text, "html.parser")

def get_dropdown_values(soup, select_id):
    dropdown = soup.find("select", {"id": select_id})
    if not dropdown:
        return []
    return [(opt["value"], opt.get_text(strip=True))
            for opt in dropdown.find_all("option") if opt.get("value")]

periode_list  = get_dropdown_values(soup, "sel_periode")
tahun_list    = get_dropdown_values(soup, "sel_tahun")
bali_pemda_list = get_dropdown_values(soup, "sel_pemda")

print(bali_pemda_list)
# Out:
# [('00', 'Provinsi Bali'), ('01', 'Kab. Badung'), ('02', 'Kab. Bangli'), ('03', 'Kab. Buleleng'), ('04', 'Kab. Gianyar'), ('05', 'Kab. Jembrana'), ('06', 'Kab. Karangasem'), ('07', 'Kab. Klungkung'), ('08', 'Kab. Tabanan'), ('09', 'Kota Denpasar'), ('--', 'Semua pemda')]

# %%
# remove pemda = "Provinsi Bali" and "Semua pemda"
bali_pemda_list = [p for p in bali_pemda_list if p[1] != "Provinsi Bali" and p[1] != "Semua Pemda"]

# %%
# Hapus tahun 2026
tahun_list = [t for t in tahun_list if t[0] != '2026']

# # Start from 2018 to shorten loop time
# tahun_list = [t for t in tahun_list if int(t[0])>2017 ]

# %%
periode_list
# Out:
# [('1', 'Januari'),
#  ('2', 'Februari'),
#  ('3', 'Maret'),
#  ('4', 'April'),
#  ('5', 'Mei'),
#  ('6', 'Juni'),
#  ('7', 'Juli'),
#  ('8', 'Agustus'),
#  ('9', 'September'),
#  ('10', 'Oktober'),
#  ('11', 'November'),
#  ('12', 'Desember')]

# %%
# Scrape the APBD data from each provinsi, periode, tahun combination
import os
import requests
import pandas as pd
from io import BytesIO, StringIO
import csv
from tqdm import tqdm
import itertools

# Base download URL (you need to confirm exact endpoint from Inspect > Network)
BASE_URL = "https://djpk.kemenkeu.go.id/portal/csv_apbd"

# Create output folder
os.makedirs("apbd_excels_bali", exist_ok=True)

# Pre-create an empty dataframe to which we'll append all the data
all_data = pd.DataFrame()

# Loop over combinations
loop_length = len(bali_pemda_list)*len(tahun_list)
i = 0

for pemda, tahun in itertools.product(bali_pemda_list, tahun_list):
    i = i+1
    print(f"Progress: {i/loop_length:.3%}")

    params_value = {
        "type": "apbd",
        "provinsi": '22', # Bali
        "periode": '1', # set static month
        "tahun": tahun[0],
        "pemda": pemda[0],
    }

    print(pemda[1], tahun[1])

    # Construct filename
    filename = f"apbd_{pemda[1]}_{tahun[1]}.xlsx"
    filepath = os.path.join("apbd_excels_bali", filename)

    try:
      print(f"Downloading {filename}...")
      r = requests.get(BASE_URL, params=params_value, timeout=60)

      raw = r.content.decode("utf-8", errors="ignore")
      reader = csv.reader(StringIO(raw), delimiter=",", quotechar='"')
      rows = list(reader)

      df = pd.DataFrame(rows[1:], columns=rows[0])  # first row as header

      # Add metadata columns
      df["pemda"] = pemda[1]
      df["periode"] = "-"
      df["tahun"] = tahun[1]
      df["provinsi"] = "Bali"

      # Append to master dataframe
      all_data = pd.concat([all_data, df], ignore_index=True)

      print(f"✅ Appended {pemda}-{tahun}, rows: {len(df)}")

    except Exception as e:
      print(f"❌ Error parsing CSV for {pemda}-{tahun}: {e}")

# Save final dataframe once
all_data.to_csv("apbd_all.csv", index=False)
print(f"🎉 Final dataframe shape: {all_data.shape}")
# Out:
# Progress: 0.606%
# Provinsi Bali 2025
# Downloading apbd_Provinsi Bali_2025.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2025', '2025'), rows: 31
# Progress: 1.212%
# Provinsi Bali 2024
# Downloading apbd_Provinsi Bali_2024.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2024', '2024'), rows: 33
# Progress: 1.818%
# Provinsi Bali 2023
# Downloading apbd_Provinsi Bali_2023.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2023', '2023'), rows: 32
# Progress: 2.424%
# Provinsi Bali 2022
# Downloading apbd_Provinsi Bali_2022.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2022', '2022'), rows: 31
# Progress: 3.030%
# Provinsi Bali 2021
# Downloading apbd_Provinsi Bali_2021.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2021', '2021'), rows: 31
# Progress: 3.636%
# Provinsi Bali 2020
# Downloading apbd_Provinsi Bali_2020.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2020', '2020'), rows: 43
# Progress: 4.242%
# Provinsi Bali 2019
# Downloading apbd_Provinsi Bali_2019.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2019', '2019'), rows: 28
# Progress: 4.848%
# Provinsi Bali 2018
# Downloading apbd_Provinsi Bali_2018.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2018', '2018'), rows: 30
# Progress: 5.455%
# Provinsi Bali 2017
# Downloading apbd_Provinsi Bali_2017.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2017', '2017'), rows: 29
# Progress: 6.061%
# Provinsi Bali 2016
# Downloading apbd_Provinsi Bali_2016.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2016', '2016'), rows: 30
# Progress: 6.667%
# Provinsi Bali 2015
# Downloading apbd_Provinsi Bali_2015.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2015', '2015'), rows: 33
# Progress: 7.273%
# Provinsi Bali 2014
# Downloading apbd_Provinsi Bali_2014.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2014', '2014'), rows: 33
# Progress: 7.879%
# Provinsi Bali 2013
# Downloading apbd_Provinsi Bali_2013.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2013', '2013'), rows: 34
# Progress: 8.485%
# Provinsi Bali 2012
# Downloading apbd_Provinsi Bali_2012.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2012', '2012'), rows: 35
# Progress: 9.091%
# Provinsi Bali 2011
# Downloading apbd_Provinsi Bali_2011.xlsx...
# ✅ Appended ('00', 'Provinsi Bali')-('2011', '2011'), rows: 36
# Progress: 9.697%
# Kab. Badung 2025
# Downloading apbd_Kab. Badung_2025.xlsx...
# ✅ Appended ('01', 'Kab. Badung')-('2025', '2025'), rows: 30
# Progress: 10.303%
# Kab. Badung 2024
# Downloading apbd_Kab. Badung_2024.xlsx...
# ✅ Appended ('01', 'Kab. Badung')-('2024', '2024'), rows: 31
# Progress: 10.909%
# Kab. Badung 2023
# Downloading apbd_Kab. Badung_2023.xlsx...
# ✅ Appended ('01', 'Kab. Badung')-('2023', '2023'), rows: 30
# Progress: 11.515%
# Kab. Badung 2022
# Downloading apbd_Kab. Badung_2022.xlsx...
# ✅ Appended ('01', 'Kab. Badung')-('2022', '2022'), rows: 33
# Progress: 12.121%
# Kab. Badung 2021
# Downloading apbd_Kab. Badung_2021.xlsx...
# ✅ Appended ('01', 'Kab. Badung')-('2021', '2021'), rows: 30
# Progress: 12.727%
# Kab. Badung 2020
# Downloading apbd_Kab. Badung_2020.xlsx...
# ✅ Appended ('01', 'Kab. Badung')-('
xlsx...
# ✅ Appended ('07', 'Kab. Klungkung')-('2014', '2014'), rows: 34
# Progress: 71.515%
# Kab. Klungkung 2013
# Downloading apbd_Kab. Klungkung_2013.xlsx...
# ✅ Appended ('07', 'Kab. Klungkung')-('2013', '2013'), rows: 33
# Progress: 72.121%
# Kab. Klungkung 2012
# Downloading apbd_Kab. Klungkung_2012.xlsx...
# ✅ Appended ('07', 'Kab. Klungkung')-('2012', '2012'), rows: 32
# Progress: 72.727%
# Kab. Klungkung 2011
# Downloading apbd_Kab. Klungkung_2011.xlsx...
# ✅ Appended ('07', 'Kab. Klungkung')-('2011', '2011'), rows: 33
# Progress: 73.333%
# Kab. Tabanan 2025
# Downloading apbd_Kab. Tabanan_2025.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2025', '2025'), rows: 30
# Progress: 73.939%
# Kab. Tabanan 2024
# Downloading apbd_Kab. Tabanan_2024.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2024', '2024'), rows: 32
# Progress: 74.545%
# Kab. Tabanan 2023
# Downloading apbd_Kab. Tabanan_2023.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2023', '2023'), rows: 31
# Progress: 75.152%
# Kab. Tabanan 2022
# Downloading apbd_Kab. Tabanan_2022.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2022', '2022'), rows: 29
# Progress: 75.758%
# Kab. Tabanan 2021
# Downloading apbd_Kab. Tabanan_2021.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2021', '2021'), rows: 42
# Progress: 76.364%
# Kab. Tabanan 2020
# Downloading apbd_Kab. Tabanan_2020.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2020', '2020'), rows: 43
# Progress: 76.970%
# Kab. Tabanan 2019
# Downloading apbd_Kab. Tabanan_2019.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2019', '2019'), rows: 33
# Progress: 77.576%
# Kab. Tabanan 2018
# Downloading apbd_Kab. Tabanan_2018.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2018', '2018'), rows: 35
# Progress: 78.182%
# Kab. Tabanan 2017
# Downloading apbd_Kab. Tabanan_2017.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2017', '2017'), rows: 34
# Progress: 78.788%
# Kab. Tabanan 2016
# Downloading apbd_Kab. Tabanan_2016.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2016', '2016'), rows: 34
# Progress: 79.394%
# Kab. Tabanan 2015
# Downloading apbd_Kab. Tabanan_2015.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2015', '2015'), rows: 37
# Progress: 80.000%
# Kab. Tabanan 2014
# Downloading apbd_Kab. Tabanan_2014.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2014', '2014'), rows: 35
# Progress: 80.606%
# Kab. Tabanan 2013
# Downloading apbd_Kab. Tabanan_2013.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2013', '2013'), rows: 35
# Progress: 81.212%
# Kab. Tabanan 2012
# Downloading apbd_Kab. Tabanan_2012.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2012', '2012'), rows: 34
# Progress: 81.818%
# Kab. Tabanan 2011
# Downloading apbd_Kab. Tabanan_2011.xlsx...
# ✅ Appended ('08', 'Kab. Tabanan')-('2011', '2011'), rows: 34
# Progress: 82.424%
# Kota Denpasar 2025
# Downloading apbd_Kota Denpasar_2025.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2025', '2025'), rows: 28
# Progress: 83.030%
# Kota Denpasar 2024
# Downloading apbd_Kota Denpasar_2024.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2024', '2024'), rows: 31
# Progress: 83.636%
# Kota Denpasar 2023
# Downloading apbd_Kota Denpasar_2023.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2023', '2023'), rows: 29
# Progress: 84.242%
# Kota Denpasar 2022
# Downloading apbd_Kota Denpasar_2022.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2022', '2022'), rows: 29
# Progress: 84.848%
# Kota Denpasar 2021
# Downloading apbd_Kota Denpasar_2021.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2021', '2021'), rows: 42
# Progress: 85.455%
# Kota Denpasar 2020
# Downloading apbd_Kota Denpasar_2020.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2020', '2020'), rows: 43
# Progress: 86.061%
# Kota Denpasar 2019
# Downloading apbd_Kota Denpasar_2019.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2019', '2019'), rows: 30
# Progress: 86.667%
# Kota Denpasar 2018
# Downloading apbd_Kota Denpasar_2018.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2018', '2018'), rows: 31
# Progress: 87.273%
# Kota Denpasar 2017
# Downloading apbd_Kota Denpasar_2017.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2017', '2017'), rows: 31
# Progress: 87.879%
# Kota Denpasar 2016
# Downloading apbd_Kota Denpasar_2016.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2016', '2016'), rows: 32
# Progress: 88.485%
# Kota Denpasar 2015
# Downloading apbd_Kota Denpasar_2015.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2015', '2015'), rows: 32
# Progress: 89.091%
# Kota Denpasar 2014
# Downloading apbd_Kota Denpasar_2014.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2014', '2014'), rows: 34
# Progress: 89.697%
# Kota Denpasar 2013
# Downloading apbd_Kota Denpasar_2013.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2013', '2013'), rows: 35
# Progress: 90.303%
# Kota Denpasar 2012
# Downloading apbd_Kota Denpasar_2012.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2012', '2012'), rows: 33
# Progress: 90.909%
# Kota Denpasar 2011
# Downloading apbd_Kota Denpasar_2011.xlsx...
# ✅ Appended ('09', 'Kota Denpasar')-('2011', '2011'), rows: 34
# Progress: 91.515%
# Semua pemda 2025
# Downloading apbd_Semua pemda_2025.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2025', '2025'), rows: 36
# Progress: 92.121%
# Semua pemda 2024
# Downloading apbd_Semua pemda_2024.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2024', '2024'), rows: 39
# Progress: 92.727%
# Semua pemda 2023
# Downloading apbd_Semua pemda_2023.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2023', '2023'), rows: 39
# Progress: 93.333%
# Semua pemda 2022
# Downloading apbd_Semua pemda_2022.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2022', '2022'), rows: 37
# Progress: 93.939%
# Semua pemda 2021
# Downloading apbd_Semua pemda_2021.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2021', '2021'), rows: 42
# Progress: 94.545%
# Semua pemda 2020
# Downloading apbd_Semua pemda_2020.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2020', '2020'), rows: 43
# Progress: 95.152%
# Semua pemda 2019
# Downloading apbd_Semua pemda_2019.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2019', '2019'), rows: 39
# Progress: 95.758%
# Semua pemda 2018
# Downloading apbd_Semua pemda_2018.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2018', '2018'), rows: 39
# Progress: 96.364%
# Semua pemda 2017
# Downloading apbd_Semua pemda_2017.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2017', '2017'), rows: 38
# Progress: 96.970%
# Semua pemda 2016
# Downloading apbd_Semua pemda_2016.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2016', '2016'), rows: 37
# Progress: 97.576%
# Semua pemda 2015
# Downloading apbd_Semua pemda_2015.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2015', '2015'), rows: 43
# Progress: 98.182%
# Semua pemda 2014
# Downloading apbd_Semua pemda_2014.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2014', '2014'), rows: 39
# Progress: 98.788%
# Semua pemda 2013
# Downloading apbd_Semua pemda_2013.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2013', '2013'), rows: 41
# Progress: 99.394%
# Semua pemda 2012
# Downloading apbd_Semua pemda_2012.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2012', '2012'), rows: 43
# Progress: 100.000%
# Semua pemda 2011
# Downloading apbd_Semua pemda_2011.xlsx...
# ✅ Appended ('--', 'Semua pemda')-('2011', '2011'), rows: 43
# 🎉 Final dataframe shape: (5583, 8)

# %%
-
